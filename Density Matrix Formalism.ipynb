# %%
from qiskit import *

# %%
import qiskit.quantum_info as qi

# %%
qc_AB = QuantumCircuit(2); qc_AB.h(0); qc_AB.cx(0,1); qc_AB.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
psiAB = qi.Statevector.from_instruction(qc_AB); psiAB.draw('latex', prefix='|\\psi{AB}\\rangle = ')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$

# %%
rhoAB = qi.DensityMatrix.from_instruction(qc_AB); rhoAB.draw('latex', prefix='|\\rho{AB}\\rangle = ')
# Out:
# $$
# |\rho{AB}\rangle =
# \begin{bmatrix}
# \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  0 & 0 & 0 & 0  \\
#  0 & 0 & 0 & 0  \\
#  \tfrac{1}{2} & 0 & 0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
qc1 = QuantumCircuit(1); qc1.h(0); qc1.z(0); qc1.s(0); qc1.draw()
# Out:
#    ┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ S ├
#    └───┘└───┘└───┘

# %%
psi1 = qi.Statevector.from_instruction(qc1); psi1.draw('latex', prefix='|\\psi{1}\\rangle = ')
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle- \frac{\sqrt{2} i}{2} |1\rangle$$

# %%
rho1 = qi.DensityMatrix.from_instruction(qc1); rho1.draw('latex', prefix='|\\rho{1}\\rangle = ')
# Out:
# $$
# |\rho{1}\rangle =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}i  \\
#  -\tfrac{1}{2}i & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import *
plot_state_city(rho1.data, title='Density Matrix')

# %%
import numpy as np
rho_H_matrix = np.array([[1/2,np.sqrt(3)/20 + 2/5],[np.sqrt(3)/20 + 2/5,1/2]])
rho_H = qi.DensityMatrix(rho_H_matrix)
rho_H.draw('latex', prefix='\\rho_H = ')
# Out:
# $$
# \rho_H =
# \begin{bmatrix}
# \tfrac{1}{2} & 0.4866  \\
#  0.4866 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$

# %%
rho_0 = 1/3*qi.DensityMatrix.from_label('1') + 2/3*qi.DensityMatrix.from_label('+')
rho_0.draw('latex', prefix='\\rho_0 = ')
# Out:
# $$
# \rho_0 =
# \begin{bmatrix}
# \tfrac{1}{3} & \tfrac{1}{3}  \\
#  \tfrac{1}{3} & \tfrac{2}{3}  \\
#  \end{bmatrix}
# $$

# %%
from qiskit.visualization import array_to_latex
Y = qi.Operator.from_label('Y')
array_to_latex(Y.data, prefix='Y =')
# Out:
# $$
# Y =
# \begin{bmatrix}
# 0 & -i  \\
#  i & 0  \\
#  \end{bmatrix}
# $$

# %%
rho_0p = rho_0.evolve(Y)
rho_0p.draw('latex', prefix='\\rho\'_0 = ')
# Out:
# $$
# \rho'_0 =
# \begin{bmatrix}
# \tfrac{2}{3} & -\tfrac{1}{3}  \\
#  -\tfrac{1}{3} & \tfrac{1}{3}  \\
#  \end{bmatrix}
# $$

# %%
rho_p = qi.DensityMatrix.from_label('+')
display(rho_p.draw('latex', prefix='\\rho_p = '))
gamma_p = rho_p.purity()
print("State purity: ", np.round(np.real(gamma_p),3))
# Out:
# $$
# \rho_p =
# \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \tfrac{1}{2} & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$
# State purity:  1.0

# %%
rho_m = 1/2*(qi.DensityMatrix.from_label('0') + qi.DensityMatrix.from_label('1'))
display(rho_m.draw('latex', prefix='\\rho_m = '))
gamma_m = rho_m.purity()
print("State purity: ", np.round(np.real(gamma_m),3))
# Out:
# $$
# \rho_m =
# \begin{bmatrix}
# \tfrac{1}{2} & 0  \\
#  0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$
# State purity:  0.5

# %%
rho_B = qi.partial_trace(rhoAB,[0])
rho_A = qi.partial_trace(rhoAB,[1])

display(rho_B.draw('latex', prefix=" \\rho_{B} = "),
        rho_A.draw('latex', prefix=" \\rho_{A} = "))
# Out:
# $$
#  \rho_{B} =
# \begin{bmatrix}
# \tfrac{1}{2} & 0  \\
#  0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$
# $$
#  \rho_{A} =
# \begin{bmatrix}
# \tfrac{1}{2} & 0  \\
#  0 & \tfrac{1}{2}  \\
#  \end{bmatrix}
# $$
